# %% [markdown]
# **Tropical Cyclone Freddy**
#
# **Pangu AI Weather Forecasts**
#
# - we have multiple leadtimes with the following initialisation times:
# - 14.02.23
# - 19.02.23
# - 23.02.23

# %% [markdown]
# **Load libraries**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
from datetime import datetime
import sys
import warnings
from glob import glob
import pandas as pd
import netCDF4 as nc
import h5netcdf

# %% [markdown]
# **Load Pangu data**

# %%
tc =  xr.open_dataset('../data/Pangu/TC_FREDDY2_20230214.nc')
tc
# Out:
# <xarray.Dataset> Size: 104MB
# Dimensions:            (longitude: 441, latitude: 81, step: 52, isobaricInhPa: 2)
# Coordinates:
#   * longitude          (longitude) float64 4kB 10.0 10.25 10.5 ... 119.8 120.0
#   * latitude           (latitude) float64 648B -10.0 -10.25 ... -29.75 -30.0
#   * step               (step) timedelta64[ns] 416B 0 days 06:00:00 ... 13 day...
#     valid_time         (step) datetime64[ns] 416B ...
#   * isobaricInhPa      (isobaricInhPa) float64 16B 850.0 500.0
#     time               datetime64[ns] 8B ...
#     meanSea            float64 8B ...
#     heightAboveGround  float64 8B ...
# Data variables:
#     msl                (step, latitude, longitude) float32 7MB ...
#     u10                (step, latitude, longitude) float32 7MB ...
#     v10                (step, latitude, longitude) float32 7MB ...
#     t2                 (step, latitude, longitude) float32 7MB ...
#     z                  (step, isobaricInhPa, latitude, longitude) float32 15MB ...
# ...

# %% [markdown]
# **Variables in Pangu**
#
# - **u10**: 10mwind in x direction
# - **v10**
# - **msl**: mean sea level pressure
# - **t2**: 2 meter temperature
# - **u**: u wind component
# - **v**
# - **z**
# - **q**: specific humidity

# %%
# plot of 2 meter temperature
fig = plt.figure(figsize=(14,3))

map_projection = ccrs.PlateCarree()

ax = plt.axes(projection=map_projection)

tc.t2.sel(step=tc.step[1]).plot(
    ax=ax,
    transform=ccrs.PlateCarree())

ax.set_title("12:00 15.02.23")

plt.tight_layout()
plt.draw()
plt.show()
