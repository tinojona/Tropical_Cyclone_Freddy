# %% [markdown]
# **Soo finden wir mal heraus ob ich mit den Freddy nc files quasi genau das gleiche machen kann wie mit ERA??**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
from datetime import datetime
import sys
import warnings
from glob import glob
import pandas as pd
import netCDF4 as nc
import h5netcdf

# %% [markdown]
# Wir haben drei Datensätze:
# - 14.02.23
# - 19.02.23
# - 23.03.23
#
# Ist die Dimension "step" quasi time?

# %%
tc =  xr.open_dataset('../data/TC_FREDDY_20230214.nc')
tc
# Out:
# C:\Users\tinos\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# <xarray.Dataset>
# Dimensions:            (longitude: 341, latitude: 81, step: 14, isobaricInhPa: 2)
# Coordinates:
#   * longitude          (longitude) float64 35.0 35.25 35.5 ... 119.5 119.8 120.0
#   * latitude           (latitude) float64 -10.0 -10.25 -10.5 ... -29.75 -30.0
#   * step               (step) timedelta64[ns] 9 days 18:00:00 ... 13 days 00:...
#     valid_time         (step) datetime64[ns] ...
#   * isobaricInhPa      (isobaricInhPa) float64 850.0 500.0
#     time               datetime64[ns] ...
#     meanSea            float64 ...
#     heightAboveGround  float64 ...
# Data variables:
#     msl                (step, latitude, longitude) float32 ...
#     u10                (step, latitude, longitude) float32 ...
#     v10                (step, latitude, longitude) float32 ...
# ...

# %%
tc
# Out:
# <xarray.Dataset>
# Dimensions:            (longitude: 341, latitude: 81, step: 14, isobaricInhPa: 2)
# Coordinates:
#   * longitude          (longitude) float64 35.0 35.25 35.5 ... 119.5 119.8 120.0
#   * latitude           (latitude) float64 -10.0 -10.25 -10.5 ... -29.75 -30.0
#   * step               (step) timedelta64[ns] 9 days 18:00:00 ... 13 days 00:...
#     valid_time         (step) datetime64[ns] ...
#   * isobaricInhPa      (isobaricInhPa) float64 850.0 500.0
#     time               datetime64[ns] ...
#     meanSea            float64 ...
#     heightAboveGround  float64 ...
# Data variables:
#     msl                (step, latitude, longitude) float32 ...
#     u10                (step, latitude, longitude) float32 ...
#     v10                (step, latitude, longitude) float32 ...
#     t2                 (step, latitude, longitude) float32 ...
#     z                  (step, isobaricInhPa, latitude, longitude) float32 ...
# ...

# %%
# fig, axs = plt.subplots(nrows=4)
fig = plt.figure(figsize=(14,6))
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)

tc.t2.sel(step=tc.step[1]).plot(
    ax=ax,
    transform=ccrs.PlateCarree())
# tc.t2[2,:,:].plot(ax=axs[1])
# tc.t2[3,:,:].plot(ax=axs[2])
# tc.t2[4,:,:].plot(ax=axs[3])

plt.tight_layout()
plt.draw()

# %%
# fig, axs = plt.subplots(nrows=4)
fig = plt.figure(figsize=(14,6))
map_projection = ccrs.PlateCarree()
ax = plt.axes(projection=map_projection)

tc.t2.sel(step=tc.step[1]).plot(
    ax=ax,
    transform=ccrs.PlateCarree())
# tc.t2[2,:,:].plot(ax=axs[1])
# tc.t2[3,:,:].plot(ax=axs[2])
# tc.t2[4,:,:].plot(ax=axs[3])

plt.tight_layout()
plt.draw()
